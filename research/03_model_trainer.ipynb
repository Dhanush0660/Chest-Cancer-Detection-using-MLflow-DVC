# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Dhanush\\Projects\\Chest-Cancer-Detection-using-MLflow-DVC\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Dhanush\\Projects\\Chest-Cancer-Detection-using-MLflow-DVC'

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class TrainingConfig:
    root_dir: Path
    trained_model_path: Path
    updated_base_model_path: Path
    training_data: Path
    params_epochs: int
    params_batch_size: int
    params_is_augmentation: bool
    params_image_size: list

# %%
from src.cnnClassifier.constants import *
from src.cnnClassifier.utils.common import read_yaml, create_directories
import tensorflow as tf

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])

        

    def get_training_config(self) -> TrainingConfig:
        training = self.config.training
        prepare_base_model = self.config.prepare_base_model
        params = self.params
        training_data = os.path.join(self.config.data_ingestion.unzip_dir, "Chest-CT-Scan-data")
        create_directories([
            Path(training.root_dir)
        ])

        training_config = TrainingConfig(
            root_dir=Path(training.root_dir),
            trained_model_path=Path(training.trained_model_path),
            updated_base_model_path=Path(prepare_base_model.updated_base_model_path),
            training_data=Path(training_data),
            params_epochs=params.EPOCHS,
            params_batch_size=params.BATCH_SIZE,
            params_is_augmentation=params.AUGMENTATION,
            params_image_size=params.IMAGE_SIZE
        )

        return training_config

# %%
import os
import urllib.request as request
from zipfile import ZipFile
import tensorflow as tf
import time

# %%
class Training:
    def __init__(self, config: TrainingConfig):
        self.config = config

    
    def get_base_model(self):
        self.model = tf.keras.models.load_model(
            self.config.updated_base_model_path
        )

    def train_valid_generator(self):

        datagenerator_kwargs = dict(
            rescale = 1./255,
            validation_split=0.20
        )

        dataflow_kwargs = dict(
            target_size=self.config.params_image_size[:-1],
            batch_size=self.config.params_batch_size,
            interpolation="bilinear"
        )

        valid_datagenerator = tf.keras.preprocessing.image.ImageDataGenerator(
            **datagenerator_kwargs
        )

        self.valid_generator = valid_datagenerator.flow_from_directory(
            directory=self.config.training_data,
            subset="validation",
            shuffle=False,
            **dataflow_kwargs
        )

        if self.config.params_is_augmentation:
            train_datagenerator = tf.keras.preprocessing.image.ImageDataGenerator(
                rotation_range=40,
                horizontal_flip=True,
                width_shift_range=0.2,
                height_shift_range=0.2,
                shear_range=0.2,
                zoom_range=0.2,
                **datagenerator_kwargs
            )
        else:
            train_datagenerator = valid_datagenerator

        self.train_generator = train_datagenerator.flow_from_directory(
            directory=self.config.training_data,
            subset="training",
            shuffle=True,
            **dataflow_kwargs
        )

    
    @staticmethod
    def save_model(path: Path, model: tf.keras.Model):
        model.save(path)



    
    def train(self):
        self.steps_per_epoch = self.train_generator.samples // self.train_generator.batch_size
        self.validation_steps = self.valid_generator.samples // self.valid_generator.batch_size

        self.model.fit(
            self.train_generator,
            epochs=self.config.params_epochs,
            steps_per_epoch=self.steps_per_epoch,
            validation_steps=self.validation_steps,
            validation_data=self.valid_generator
        )

        self.save_model(
            path=self.config.trained_model_path,
            model=self.model
        )

# %%
try:
    config = ConfigurationManager()
    training_config = config.get_training_config()
    training = Training(config=training_config)
    training.get_base_model()
    training.train_valid_generator()
    training.train()
    
except Exception as e:
    raise e
# Out:
# [2024-02-03 15:38:34,725: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2024-02-03 15:38:34,729: INFO: common: yaml file: params.yaml loaded successfully]
# [2024-02-03 15:38:34,732: INFO: common: created directory at: artifacts]
# [2024-02-03 15:38:34,733: INFO: common: created directory at: artifacts\training]
# Found 68 images belonging to 2 classes.
# Found 275 images belonging to 2 classes.
# Epoch 1/100
# 17/17 [==============================] - 25s 1s/step - loss: 11.3153 - accuracy: 0.5753 - val_loss: 12.0345 - val_accuracy: 0.3906
# Epoch 2/100
# 17/17 [==============================] - 24s 1s/step - loss: 12.8252 - accuracy: 0.5560 - val_loss: 9.7029 - val_accuracy: 0.6094
# Epoch 3/100
# 17/17 [==============================] - 23s 1s/step - loss: 6.6610 - accuracy: 0.6641 - val_loss: 6.6401 - val_accuracy: 0.4062
# Epoch 4/100
# 17/17 [==============================] - 23s 1s/step - loss: 8.7941 - accuracy: 0.6139 - val_loss: 2.5445 - val_accuracy: 0.8594
# Epoch 5/100
# 17/17 [==============================] - 23s 1s/step - loss: 4.0129 - accuracy: 0.7452 - val_loss: 1.3225 - val_accuracy: 0.8750
# Epoch 6/100
# 17/17 [==============================] - 23s 1s/step - loss: 3.0337 - accuracy: 0.7954 - val_loss: 0.8872 - val_accuracy: 0.8750
# Epoch 7/100
# 17/17 [==============================] - 23s 1s/step - loss: 6.0692 - accuracy: 0.6718 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 8/100
# 17/17 [==============================] - 23s 1s/step - loss: 2.7284 - accuracy: 0.7978 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 9/100
# 17/17 [==============================] - 23s 1s/step - loss: 3.4763 - accuracy: 0.8417 - val_loss: 5.9745e-05 - val_accuracy: 1.0000
# Epoch 10/100
# 17/17 [==============================] - 22s 1s/step - loss: 2.1888 - accuracy: 0.8649 - val_loss: 0.0999 - val_accuracy: 0.9844
# Epoch 11/100
# 17/17 [==============================] - 23s 1s/step - loss: 2.5298 - accuracy: 0.8031 - val_loss: 1.1375 - val_accuracy: 0.8750
# Epoch 12/100
# 17/17 [==============================] - 23s 1s/step - loss: 1.5472 - accuracy: 0.8378 - val_loss: 2.8356 - val_accuracy: 0.7031
# Epoch 13/100
# 17/17 [==============================] - 23s 1s/step - loss: 1.1881 - accuracy: 0.8726 - val_loss: 1.7915 - val_accuracy: 0.7344
# Epoch 14/100
# 17/17 [==============================] - 23s 1s/step - loss: 2.4264 - accuracy: 0.8263 - val_loss: 1.2984e-04 - val_accuracy: 1.0000
# Epoch 15/100
# 17/17 [==============================] - 25s 1s/step - loss: 0.9303 - accuracy: 0.9073 - val_loss: 4.0423e-04 - val_accuracy: 1.0000
# Epoch 16/100
# 17/17 [==============================] - 23s 1s/step - loss: 1.6263 - accuracy: 0.8649 - val_loss: 1.6221e-05 - val_accuracy: 1.0000
# Epoch 17/100
# 17/17 [==============================] - 22s 1s/step - loss: 2.2812 - accuracy: 0.8417 - val_loss: 0.5599 - val_accuracy: 0.8750
# Epoch 18/100
# 17/17 [==============================] - 22s 1s/step - loss: 1.5376 - accuracy: 0.8378 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 19/100
# 17/17 [==============================] - 23s 1s/step - loss: 0.3595 - accuracy: 0.9344 - val_loss: 7.1587e-06 - val_accuracy: 1.0000
# Epoch 20/100
# 17/17 [==============================] - 26s 2s/step - loss: 0.5381 - accuracy: 0.9151 - val_loss: 0.0448 - val_accuracy: 0.9844
# Epoch 21/100
# 17/17 [==============================] - 25s 1s/step - loss: 1.0969 - accuracy: 0.9151 - val_loss: 8.6693e-05 - val_accuracy: 1.0000
# Epoch 22/100
# 17/17 [==============================] - 24s 1s/step - loss: 1.3484 - accuracy: 0.8726 - val_loss: 3.0659e-06 - val_accuracy: 1.0000
# Epoch 23/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.3179 - accuracy: 0.9459 - val_loss: 9.0891e-06 - val_accuracy: 1.0000
# Epoch 24/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.7253 - accuracy: 0.9266 - val_loss: 4.6092e-05 - val_accuracy: 1.0000
# Epoch 25/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.9000 - accuracy: 0.9112 - val_loss: 0.0162 - val_accuracy: 0.9844
# Epoch 26/100
# 17/17 [==============================] - 22s 1s/step - loss: 1.1270 - accuracy: 0.8996 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 27/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.8460 - accuracy: 0.9112 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 28/100
# 17/17 [==============================] - 23s 1s/step - loss: 0.3797 - accuracy: 0.9421 - val_loss: 9.2039e-04 - val_accuracy: 1.0000
# Epoch 29/100
# 17/17 [==============================] - 22s 1s/step - loss: 1.1924 - accuracy: 0.8880 - val_loss: 0.0241 - val_accuracy: 0.9844
# Epoch 30/100
# 17/17 [==============================] - 22s 1s/step - loss: 1.1967 - accuracy: 0.8610 - val_loss: 3.8671 - val_accuracy: 0.6719
# Epoch 31/100
# 17/17 [==============================] - 22s 1s/step - loss: 1.1198 - accuracy: 0.8842 - val_loss: 1.3392e-06 - val_accuracy: 1.0000
# Epoch 32/100
# 17/17 [==============================] - 23s 1s/step - loss: 0.4265 - accuracy: 0.9421 - val_loss: 2.6541e-06 - val_accuracy: 1.0000
# Epoch 33/100
# 17/17 [==============================] - 23s 1s/step - loss: 0.3192 - accuracy: 0.9412 - val_loss: 1.3527e-04 - val_accuracy: 1.0000
# Epoch 34/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.2487 - accuracy: 0.9459 - val_loss: 3.2817e-06 - val_accuracy: 1.0000
# Epoch 35/100
# 17/17 [==============================] - 23s 1s/step - loss: 0.5560 - accuracy: 0.9112 - val_loss: 5.8905e-04 - val_accuracy: 1.0000
# Epoch 36/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.8003 - accuracy: 0.9189 - val_loss: 4.2307e-04 - val_accuracy: 1.0000
# Epoch 37/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.6730 - accuracy: 0.8958 - val_loss: 0.0562 - val_accuracy: 0.9844
# Epoch 38/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.3636 - accuracy: 0.9344 - val_loss: 2.6821e-05 - val_accuracy: 1.0000
# Epoch 39/100
# 17/17 [==============================] - 22s 1s/step - loss: 2.4110 - accuracy: 0.8494 - val_loss: 3.9189e-06 - val_accuracy: 1.0000
# Epoch 40/100
# 17/17 [==============================] - 23s 1s/step - loss: 0.2638 - accuracy: 0.9498 - val_loss: 1.2011e-05 - val_accuracy: 1.0000
# Epoch 41/100
# 17/17 [==============================] - 23s 1s/step - loss: 0.3839 - accuracy: 0.9266 - val_loss: 6.9663e-07 - val_accuracy: 1.0000
# Epoch 42/100
# 17/17 [==============================] - 23s 1s/step - loss: 0.2440 - accuracy: 0.9596 - val_loss: 8.8730e-06 - val_accuracy: 1.0000
# Epoch 43/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.3544 - accuracy: 0.9421 - val_loss: 5.9536e-04 - val_accuracy: 1.0000
# Epoch 44/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.2725 - accuracy: 0.9575 - val_loss: 6.1653e-07 - val_accuracy: 1.0000
# Epoch 45/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.5662 - accuracy: 0.9151 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 46/100
# 17/17 [==============================] - 23s 1s/step - loss: 0.4290 - accuracy: 0.9338 - val_loss: 3.8658e-04 - val_accuracy: 1.0000
# Epoch 47/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.9380 - accuracy: 0.9305 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 48/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.5219 - accuracy: 0.9228 - val_loss: 2.2667e-06 - val_accuracy: 1.0000
# Epoch 49/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.6252 - accuracy: 0.9266 - val_loss: 1.7303e-06 - val_accuracy: 1.0000
# Epoch 50/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.3016 - accuracy: 0.9421 - val_loss: 4.8708e-04 - val_accuracy: 1.0000
# Epoch 51/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.5127 - accuracy: 0.9073 - val_loss: 0.7226 - val_accuracy: 0.8750
# Epoch 52/100
# 17/17 [==============================] - 23s 1s/step - loss: 0.4095 - accuracy: 0.9537 - val_loss: 2.9317e-05 - val_accuracy: 1.0000
# Epoch 53/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.7062 - accuracy: 0.9305 - val_loss: 4.9830e-05 - val_accuracy: 1.0000
# Epoch 54/100
# 17/17 [==============================] - 23s 1s/step - loss: 0.2479 - accuracy: 0.9596 - val_loss: 8.7544e-07 - val_accuracy: 1.0000
# Epoch 55/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.4306 - accuracy: 0.9228 - val_loss: 5.3869e-05 - val_accuracy: 1.0000
# Epoch 56/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.3288 - accuracy: 0.9537 - val_loss: 3.7067e-07 - val_accuracy: 1.0000
# Epoch 57/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.4048 - accuracy: 0.9228 - val_loss: 3.1851e-07 - val_accuracy: 1.0000
# Epoch 58/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.3589 - accuracy: 0.9498 - val_loss: 5.2526e-07 - val_accuracy: 1.0000
# Epoch 59/100
# 17/17 [==============================] - 24s 1s/step - loss: 0.4010 - accuracy: 0.9266 - val_loss: 1.1078e-04 - val_accuracy: 1.0000
# Epoch 60/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.1930 - accuracy: 0.9498 - val_loss: 1.5665e-06 - val_accuracy: 1.0000
# Epoch 61/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.8995 - accuracy: 0.9382 - val_loss: 1.1194e-06 - val_accuracy: 1.0000
# Epoch 62/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.2688 - accuracy: 0.9537 - val_loss: 2.0740e-05 - val_accuracy: 1.0000
# Epoch 63/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.1849 - accuracy: 0.9768 - val_loss: 1.9231e-05 - val_accuracy: 1.0000
# Epoch 64/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.2016 - accuracy: 0.9614 - val_loss: 7.8187e-05 - val_accuracy: 1.0000
# Epoch 65/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.1733 - accuracy: 0.9653 - val_loss: 8.5732e-06 - val_accuracy: 1.0000
# Epoch 66/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.1324 - accuracy: 0.9653 - val_loss: 1.2479e-06 - val_accuracy: 1.0000
# Epoch 67/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.2229 - accuracy: 0.9614 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 68/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.1453 - accuracy: 0.9730 - val_loss: 5.0105e-07 - val_accuracy: 1.0000
# Epoch 69/100
# 17/17 [==============================] - 22s 1s/step - loss: 1.0938 - accuracy: 0.8764 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 70/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.1640 - accuracy: 0.9614 - val_loss: 1.2628e-04 - val_accuracy: 1.0000
# Epoch 71/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.2496 - accuracy: 0.9575 - val_loss: 6.0008e-04 - val_accuracy: 1.0000
# Epoch 72/100
# 17/17 [==============================] - 22s 1s/step - loss: 2.1562 - accuracy: 0.9189 - val_loss: 1.4566e-06 - val_accuracy: 1.0000
# Epoch 73/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.3119 - accuracy: 0.9382 - val_loss: 1.1697e-06 - val_accuracy: 1.0000
# Epoch 74/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.2586 - accuracy: 0.9537 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 75/100
# 17/17 [==============================] - 24s 1s/step - loss: 0.4527 - accuracy: 0.9112 - val_loss: 5.3474e-06 - val_accuracy: 1.0000
# Epoch 76/100
# 17/17 [==============================] - 23s 1s/step - loss: 0.1865 - accuracy: 0.9421 - val_loss: 7.6731e-04 - val_accuracy: 1.0000
# Epoch 77/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.1704 - accuracy: 0.9691 - val_loss: 2.0768e-04 - val_accuracy: 1.0000
# Epoch 78/100
# 17/17 [==============================] - 23s 1s/step - loss: 0.2357 - accuracy: 0.9614 - val_loss: 3.9319e-06 - val_accuracy: 1.0000
# Epoch 79/100
# 17/17 [==============================] - 24s 1s/step - loss: 0.4728 - accuracy: 0.9301 - val_loss: 8.0349e-06 - val_accuracy: 1.0000
# Epoch 80/100
# 17/17 [==============================] - 23s 1s/step - loss: 0.1914 - accuracy: 0.9653 - val_loss: 5.6810e-07 - val_accuracy: 1.0000
# Epoch 81/100
# 17/17 [==============================] - 23s 1s/step - loss: 0.2800 - accuracy: 0.9575 - val_loss: 9.1109e-04 - val_accuracy: 1.0000
# Epoch 82/100
# 17/17 [==============================] - 23s 1s/step - loss: 0.1842 - accuracy: 0.9537 - val_loss: 4.5086e-05 - val_accuracy: 1.0000
# Epoch 83/100
# 17/17 [==============================] - 24s 1s/step - loss: 0.0390 - accuracy: 0.9884 - val_loss: 1.4864e-06 - val_accuracy: 1.0000
# Epoch 84/100
# 17/17 [==============================] - 23s 1s/step - loss: 0.1168 - accuracy: 0.9614 - val_loss: 5.4202e-07 - val_accuracy: 1.0000
# Epoch 85/100
# 17/17 [==============================] - 23s 1s/step - loss: 0.1606 - accuracy: 0.9653 - val_loss: 0.0425 - val_accuracy: 0.9688
# Epoch 86/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.1912 - accuracy: 0.9614 - val_loss: 1.4467e-05 - val_accuracy: 1.0000
# Epoch 87/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.1068 - accuracy: 0.9768 - val_loss: 2.6581e-05 - val_accuracy: 1.0000
# Epoch 88/100
# 17/17 [==============================] - 23s 1s/step - loss: 0.2510 - accuracy: 0.9653 - val_loss: 1.5342e-05 - val_accuracy: 1.0000
# Epoch 89/100
# 17/17 [==============================] - 23s 1s/step - loss: 0.1155 - accuracy: 0.9768 - val_loss: 8.7169e-07 - val_accuracy: 1.0000
# Epoch 90/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.1631 - accuracy: 0.9575 - val_loss: 2.1028e-04 - val_accuracy: 1.0000
# Epoch 91/100
# 17/17 [==============================] - 23s 1s/step - loss: 0.0687 - accuracy: 0.9691 - val_loss: 8.4936e-07 - val_accuracy: 1.0000
# Epoch 92/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.1015 - accuracy: 0.9730 - val_loss: 4.5950e-06 - val_accuracy: 1.0000
# Epoch 93/100
# 17/17 [==============================] - 23s 1s/step - loss: 0.2037 - accuracy: 0.9614 - val_loss: 1.3057e-04 - val_accuracy: 1.0000
# Epoch 94/100
# 17/17 [==============================] - 23s 1s/step - loss: 0.1471 - accuracy: 0.9537 - val_loss: 3.1913e-04 - val_accuracy: 1.0000
# Epoch 95/100
# 17/17 [==============================] - 23s 1s/step - loss: 0.3609 - accuracy: 0.9382 - val_loss: 1.4809e-04 - val_accuracy: 1.0000
# Epoch 96/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.1277 - accuracy: 0.9691 - val_loss: 0.0247 - val_accuracy: 0.9844
# Epoch 97/100
# 17/17 [==============================] - 23s 1s/step - loss: 0.1632 - accuracy: 0.9669 - val_loss: 2.4959e-07 - val_accuracy: 1.0000
# Epoch 98/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.0638 - accuracy: 0.9846 - val_loss: 1.7268e-05 - val_accuracy: 1.0000
# Epoch 99/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.0971 - accuracy: 0.9730 - val_loss: 1.8068e-07 - val_accuracy: 1.0000
# Epoch 100/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.1371 - accuracy: 0.9807 - val_loss: 4.2090e-06 - val_accuracy: 1.0000
# c:\Users\dhanu\anaconda3\envs\cancer\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
